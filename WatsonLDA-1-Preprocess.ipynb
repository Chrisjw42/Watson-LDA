# %%
import os
import numpy as np
import pandas as pd
import ast
import string
import random
import string
import random
import nltk
import pickle
import wordcloud
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from collections import defaultdict
from gensim import corpora, models, similarities

# %%
# THIS NEEDS TO BE RUN ONCE ON ANY GIVEN SYSTEM
#nltk.download('wordnet')

# %% [markdown]
# # Cleaning

# %%
def removeDodgyEntries(data):
    """
    Drop all rows that are not able to be literal_eval'ed
    """
    dodgyEntries = []
    for i in data.index:
        try:
            ast.literal_eval(data.loc[i]["text"])
        except:
            dodgyEntries.append(i)
    print("Removed {} rows due to literal_eval issues".format(len(dodgyEntries)))
    return data.drop(dodgyEntries)

    
def loadScrapeOutput():
    """
    Load the various scarping outpus, join them in one DF, return
    """
    dataFb = pd.read_csv("data/facebookArticlesClean.csv", encoding="ISO-8859-1")
    dataG = pd.read_csv("data/googlePagesClean.csv", encoding="ISO-8859-1")
    data = dataG[dataG.columns[2:]].append(dataFb[dataFb.columns[2:]], ignore_index=True)
    
    # Very basic initial scraping
    def filtering(s):
        s = s.lower()
        s = ''.join([c for c in s if c in string.printable]) # Get rid of non ascii whitespace chars, e.g. japanese
        s = s.strip() # Get rid of whitespace AFTER removing chars
        return s
    

    data["text"] = data["TRANSLATED_CONTENT"].apply(filtering)
    data = removeDodgyEntries(data)
    
    # Evaluate the string representation of the list
    data["text_list"] = data["text"].apply(ast.literal_eval)
    
    data.drop(["CONTENT", "TRANSLATED_CONTENT", "FIRST_PARAGRAPH"], axis=1, inplace=True)
    
    return data

data = loadScrapeOutput()
# Out:
# Removed 1 rows due to literal_eval issues

# %%
def explode(s):
    return " ".join(s)

data["text_full"] = data["text_list"].apply(explode)
data.drop("text", axis=1, inplace=True)

# %% [markdown]
# ### remove punctuation

# %%
def splitcol(s):
    # All puncuation characters to be ignored
    exclude = set(string.punctuation)
    # In string form
    excludestr = ''.join(exclude)

    s = ''.join([c for c in s if c not in exclude]) # Removes punctuation
    s = [x for x in s.split(" ") if x != ""] # Accounts for double whitespace
    return s

def spaceseparate(s):
    s = ' '.join(s)
    return s

# Create a column that is every word, split. 
data["text_split"] = data["text_full"].apply(splitcol)
data["text_full"] = data["text_split"].apply(spaceseparate)

# %%
def printCorpusInfo(data):
    documents = data["text_full"].values
    documentsSplit = data["text_split"].values

    words = []

    # Convert to one giant list
    for i in documentsSplit:
        words.extend(i)

    uniqueWords = set(words)

    print("Number of documents in the corpus:\t", len(data))
    print("Number of words in the corpus:\t\t", len(words))
    print("Number of UNIQUE words in the corpus: \t", len(uniqueWords))
    print("Mean document Length: \t\t\t", len(words)/len(data))
    
printCorpusInfo(data)
# Out:
# Number of documents in the corpus:	 2607
# Number of words in the corpus:		 1699654
# Number of UNIQUE words in the corpus: 	 64525
# Mean document Length: 			 651.957805907173

# %% [markdown]
# # Preparation - Creating the Corpos
#
# In this notebook the data is further prepared. The main task is to identify the tokenisation of the words and lemmatise them.
#
# ### Lemmatisation Examples:
#
# - Guns -> Gun
# - Swimming -> Swim
# - Swum -> Swim

# %% [markdown]
# ### Pos_tag the words, giving us tags that indicate "noun", "verb", etc

# %%
data["text_tagged"] = data["text_split"].apply(nltk.pos_tag)

# %%
def get_wordnet_pos(treebank_tag):
    """Convert the NLTK tokenisation to wordnet tags. This allows them to be interpreted by the wordnet lemmatiser"""
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

# %%
def lemmatise(s):
    # Instantiate a lemmatizer
    wnLem = nltk.stem.WordNetLemmatizer()
    """Lemmatization function that expects pos information (whether a word is verb, noun, etc.)"""
    """Input: [word, posInfo]"""
    #print(s)
    #print([x[0] for x in s])
    
    def lemWord(w):
        tag = get_wordnet_pos(w[1])
        if tag != None:
            return wnLem.lemmatize(w[0], pos=tag)
        else:
            return wnLem.lemmatize(w[0])

    return [lemWord(x) for x in s]

# %%
data["text_lem"] = data["text_tagged"].apply(lemmatise)

# %%
# We only care about this column now
corpus = data[["text_lem"]]

# %%
corpus.to_csv("data/corpus_df.csv")

# %%
def getRankedFrequency(data):
    frequency = defaultdict(int)
    for doc in data["text_lem"]:
        for word in doc:
            frequency[word] += 1

    filt = dict(frequency)

    f = sorted(filt.items(), key=lambda x: x[1])
    f.reverse()
    return f

# %%
getRankedFrequency(corpus)
# Out:
# [('the', 75229),
#  ('and', 55626),
#  ('be', 50469),
#  ('to', 48533),
#  ('a', 46750),
#  ('of', 41707),
#  ('in', 28074),
#  ('for', 19283),
#  ('you', 18483),
#  ('it', 18305),
#  ('that', 15767),
#  ('your', 15561),
#  ('with', 14878),
#  ('have', 13391),
#  ('on', 11718),
#  ('or', 10127),
#  ('can', 9979),
#  ('this', 9096),
#  ('i', 8167),
#  ('from', 7900),
#  ('at', 6705),
#  ('we', 6248),
#  ('by', 5948),
#  ('but', 5862),
#  ('not', 5670),
#  ('if', 5560),
#  ('more', 5383),
#  ('an', 5374),
#  ('all', 5119),
#  ('also', 4876),
#  ('will', 4860),
#  ('hong', 4813),
#  ('say', 4788),
#  ('our', 4762),
#  ('use', 4730),
#  ('do', 4572),
#  ('get', 4529),
#  ('make', 4497),
#  ('one', 4493),
#  ('up', 4051),
#  ('so', 4023),
#  ('kong', 4011),
#  ('when', 3924),
#  ('about', 3772),
#  ('which', 3726),
#  ('out', 3682),
#  ('time', 3641),
#  ('my', 3628),
#  ('help', 3572),
#  ('they', 3570),
#  ('their', 3440),
#  ('health', 3399),
#  ('like', 3337),
#  ('take', 3332),
#  ('body', 3248),
#  ('there', 3238),
#  ('some', 3188),
#  ('may', 3086),
#  ('her', 3054),
#  ('people', 3006),
#  ('he', 2983),
#  ('day', 2953),
#  ('who', 2918),
#  ('go', 2895),
#  ('just', 2846),
#  ('find', 2697),
#  ('she', 2645),
#  ('other', 2628),
#  ('good', 2609),
#  ('food', 2605),
#  ('how', 2483),
#  ('these', 2435),
#  ('than', 2416),
#  ('work', 2414),
#  ('what', 2397),
#  ('most', 2374),
#  ('youre', 2340),
#  ('need', 2327),
#  ('know', 2309),
#  ('look', 2280),
#  ('include', 2247),
#  ('new', 2211),
#  ('after', 2197),
#  ('any', 2127),
#  ('into', 2104),
#  ('year', 2070),
#  ('no', 2065),
#  ('his', 2049),
#  ('life', 2037),
#  ('even', 2030),
#  ('way', 2019),
#  ('best', 2004),
#  ('well', 1988),
#  ('many', 1958),
#  ('them', 1944),
#  ('only', 1900),
#  ('such', 1865),
#  ('offer', 1849),
#  ('want', 1810),
#  ('u', 1784),
#  ('feel', 1780),
#  ('eat', 1764),
#  ('come', 1763),
#  ('cause', 1751),
#  ('while', 1738),
#  ('skin', 1716),
#  ('because', 1715),
#  ('dont', 1676),
#  ('high', 1662),
#  ('start', 1646),
#  ('back', 1634),
#  ('much', 1634),
#  ('me', 1620),
#  ('as', 1617),
#  ('over', 1608),
#  ('keep', 1595),
#  ('should', 1584),
#  ('here', 1565),
#  ('through', 1552),
#  ('image', 1542),
#  ('see', 1532),
#  ('first', 1528),
#  ('give', 1517),
#  ('experience', 1511),
#  ('before', 1499),
#  ('product', 1484),
#  ('study', 1483),
#  ('woman', 1465),
#  ('then', 1459),
#  ('try', 1445),
#  ('healthy', 1444),
#  ('every', 1423),
#  ('two', 1417),
#  ('water', 1366),
#  ('great', 1349),
#  ('think', 1349),
#  ('blood', 1346),
#  ('disease', 1340),
#  ('city', 1335),
#  ('those', 1332),
#  ('where', 1315),
#  ('provide', 1315),
#  ('thing', 1309),
#  ('drink', 1309),
#  ('diet', 1308),
#  ('very', 1306),
#  ('right', 1305),
#  ('pain', 1304),
#  ('too', 1289),
#  ('change', 1287),
#  ('sleep', 1281),
#  ('world', 1260),
#  ('down', 1255),
#  ('service', 1220),
#  ('level', 1217),
#  ('show', 1215),
#  ('risk', 1208),
#  ('add', 1204),
#  ('now', 1201),
#  ('weight', 1195),
#  ('love', 1188),
#  ('place', 1183),
#  ('home', 1183),
#  ('during', 1168),
#  ('treatment', 1152),
#  ('cancer', 1143),
#  ('oil', 1130),
#  ('long', 1128),
#  ('learn', 1128),
#  ('off', 1126),
#  ('support', 1114),
#  ('could', 1110),
#  ('information', 1110),
#  ('around', 1105),
#  ('close', 1089),
#  ('fat', 1076),
#  ('would', 1074),
#  ('little', 1054),
#  ('exercise', 1054),
#  ('restaurant', 1050),
#  ('part', 1050),
#  ('few', 1044),
#  ('hour', 1041),
#  ('between', 1040),
#  ('child', 1037),
#  ('never', 1036),
#  ('shop', 1035),
#  ('result', 1035),
#  ('really', 1033),
#  ('sure', 1032),
#  ('both', 1031),
#  ('effect', 1021),
#  ('spot', 1018),
#  ('increase', 1003),
#  ('bar', 1002),
#  ('week', 992),
#  ('via', 983),
#  ('heart', 979),
#  ('thats', 978),
#  ('2', 977),
#  ('problem', 977),
#  ('reduce', 973),
#  ('vitamin', 970),
#  ('hair', 963),
#  ('patient', 962),
#  ('still', 961),
#  ('courtesy', 957),
#  ('each', 956),
#  ('call', 952),
#  ('care', 951),
#  ('1', 948),
#  ('student', 945),
#  ('different', 944),
#  ('system', 929),
#  ('research', 927),
#  ('event', 924),
#  ('improve', 920),
#  ('dr', 917),
#  ('something', 913),
#  ('without', 910),
#  ('natural', 910),
#  ('head', 904),
#  ('family', 904),
#  ('low', 898),
#  ('medical', 896),
#  ('street', 893),
#  ('group', 893),
#  ('road', 888),
#  ('lead', 888),
#  ('age', 887),
#  ('often', 886),
#  ('doctor', 882),
#  ('always', 882),
#  ('might', 881),
#  ('open', 881),
#  ('become', 881),
#  ('important', 879),
#  ('tell', 876),
#  ('benefit', 874),
#  ('mean', 873),
#  ('symptom', 864),
#  ('own', 860),
#  ('live', 851),
#  ('area', 846),
#  ('sassy', 845),
#  ('special', 845),
#  ('three', 841),
#  ('why', 837),
#  ('easy', 835),
#  ('lot', 833),
#  ('stress', 832),
#  ('medicine', 831),
#  ('set', 827),
#  ('youll', 823),
#  ('protein', 815),
#  ('same', 801),
#  ('course', 795),
#  ('person', 793),
#  ('3', 791),
#  ('10', 789),
#  ('control', 788),
#  ('top', 787),
#  ('type', 787),
#  ('hand', 787),
#  ('accord', 786),
#  ('small', 786),
#  ('condition', 779),
#  ('share', 775),
#  ('treat', 773),
#  ('muscle', 771),
#  ('perfect', 769),
#  ('free', 767),
#  ('site', 766),
#  ('check', 755),
#  ('bring', 755),
#  ('available', 754),
#  ('month', 753),
#  ('im', 751),
#  ('another', 750),
#  ('big', 749),
#  ('order', 749),
#  ('create', 748),
#  ('point', 746),
#  ('contain', 742),
#  ('tea', 739),
#  ('follow', 739),
#  ('quality', 738),
#  ('girl', 734),
#  ('university', 730),
#  ('sugar', 728),
#  ('minute', 718),
#  ('leave', 718),
#  ('option', 716),
#  ('however', 713),
#  ('put', 712),
#  ('friend', 709),
#  ('side', 709),
#  ('away', 706),
#  ('form', 706),
#  ('meal', 705),
#  ('sex', 703),
#  ('modal', 702),
#  ('chinese', 700),
#  ('common', 698),
#  ('pound', 694),
#  ('daily', 694),
#  ('night', 689),
#  ('ask', 688),
#  ('let', 688),
#  ('ingredient', 680),
#  ('key', 679),
#  ('per', 678),
#  ('serve', 676),
#  ('guide', 676),
#  ('since', 668),
#  ('yourself', 667),
#  ('end', 663),
#  ('less', 662),
#  ('enjoy', 662),
#  ('content', 659),
#  ('central', 655),
#  ('recommend', 654),
#  ('whether', 653),
#  ('mind', 651),
#  ('lose', 650),
#  ('old', 650),
#  ('face', 649),
#  ('develop', 648),
#  ('book', 645),
#  ('amount', 644),
#  ('run', 641),
#  ('design', 641),
#  ('under', 640),
#  ('fruit', 639),
#  ('next', 638),
#  ('partner', 636),
#  ('eye', 636),
#  ('him', 633),
#  ('full', 633),
#  ('store', 633),
#  ('number', 632),
#  ('process', 629),
#  ('move', 627),
#  ('talk', 625),
#  ('5', 620),
#  ('activity', 620),
#  ('actually', 620),
#  ('once', 619),
#  ('baby', 613),
#  ('happy', 612),
#  ('along', 612),
#  ('enough', 608),
#  ('last', 607),
#  ('turn', 606),
#  ('cell', 605),
#  ('issue', 604),
#  ('energy', 601),
#  ('men', 599),
#  ('fresh', 598),
#  ('loss', 598),
#  ('choose', 598),
#  ('search', 597),
#  ('range', 597),
#  ('data', 595),
#  ('especially', 591),
#  ('plan', 589),
#  ('until', 586),
#  ('allow', 586),
#  ('reason', 583),
#  ('test', 581),
#  ('case', 580),
#  ('mental', 578),
#  ('prevent', 578),
#  ('hot', 572),
#  ('website', 572),
#  ('stay', 571),
#  ('cant', 570),
#  ('walk', 568),
#  ('hard', 567),
#  ('continue', 565),
#  ('feature', 564),
#  ('facebook', 563),
#  ('practice', 563),
#  ('personal', 560),
#  ('secret', 558),
#  ('light', 557),
#  ('source', 557),
#  ('understand', 555),
#  ('truly', 552),
#  ('sign', 552),
#  ('public', 542),
#  ('state', 540),
#  ('receive', 539),
#  ('doesnt', 537),
#  ('wine', 536),
#  ('affect', 536),
#  ('foot', 535),
#  ('online', 535),
#  ('read', 534),
#  ('bad', 529),
#  ('4', 526),
#  ('term', 526),
#  ('press', 524),
#  ('wan', 521),
#  ('stop', 520),
#  ('report', 520),
#  ('avoid', 519),
#  ('base', 516),
#  ('play', 516),
#  ('country', 516),
#  ('calorie', 514),
#  ('grow', 513),
#  ('able', 513),
#  ('school', 512),
#  ('green', 511),
#  ('large', 511),
#  ('others', 510),
#  ('whole', 508),
#  ('medium', 508),
#  ('news', 508),
#  ('visit', 503),
#  ('al', 502),
#  ('happen', 502),
#  ('usually', 502),
#  ('local', 502),
#  ('tip', 500),
#  ('simple', 500),
#  ('focus', 499),
#  ('strong', 498),
#  ('workout', 497),
#  ('ever', 497),
#  ('name', 497),
#  ('social', 496),
#  ('cold', 496),
#  ('policy', 496),
#  ('house', 495),
#  ('early', 494),
#  ('physical', 493),
#  ('menu', 492),
#  ('consider', 492),
#  ('brain', 491),
#  ('post', 491),
#  ('list', 490),
#  ('20', 490),
#  ('2018', 488),
#  ('goto', 487),
#  ('everything', 487),
#  ('spend', 486),
#  ('dish', 484),
#  ('though', 484),
#  ('style', 482),
#  ('drug', 482),
#  ('beach', 481),
#  ('professional', 481),
#  ('example', 481),
#  ('young', 479),
#  ('please', 479),
#  ('human', 477),
#  ('fact', 475),
#  ('effective', 475),
#  ('price', 474),
#  ('four', 474),
#  ('second', 474),
#  ('position', 473),
#  ('together', 472),
#  ('choice', 471),
#  ('coffee', 467),
#  ('acid', 467),
#  ('due', 466),
#  ('write', 464),
#  ('morning', 464),
#  ('c', 464),
#  ('team', 463),
#  ('egg', 462),
#  ('brand', 462),
#  ('instagram', 461),
#  ('pressure', 461),
#  ('suggest', 460),
#  ('white', 460),
#  ('build', 459),
#  ('isnt', 458),
#  ('real', 458),
#  ('30', 458),
#  ('possible', 458),
#  ('travel', 457),
#  ('room', 456),
#  ('step', 455),
#  ('center', 455),
#  ('acupuncture', 452),
#  ('class', 451),
#  ('infection', 450),
#  ('theyre', 449),
#  ('favourite', 448),
#  ('didnt', 447),
#  ('balance', 447),
#  ('seem', 446),
#  ('must', 446),
#  ('meat', 445),
#  ('juice', 445),
#  ('hold', 445),
#  ('6', 444),
#  ('likely', 442),
#  ('apply', 441),
#  ('red', 441),
#  ('relationship', 441),
#  ('summer', 440),
#  ('least', 438),
#  ('training', 437),
#  ('view', 437),
#  ('fitness', 436),
#  ('require', 436),
#  ('late', 436),
#  ('member', 434),
#  ('sweet', 433),
#  ('five', 432),
#  ('disorder', 432),
#  ('window', 432),
#  ('therapy', 432),
#  ('line', 432),
#  ('cooky', 431),
#  ('begin', 431),
#  ('individual', 431),
#  ('contact', 430),
#  ('immune', 430),
#  ('milk', 428),
#  ('produce', 427),
#  ('cut', 426),
#  ('space', 425),
#  ('period', 425),
#  ('percent', 424),
#  ('again', 424),
#  ('gift', 421),
#  ('within', 421),
#  ('beer', 419),
#  ('function', 418),
#  ('escape', 417),
#  ('air', 415),
#  ('community', 414),
#  ('professor', 414),
#  ('anxiety', 413),
#  ('someone', 413),
#  ('deal', 412),
#  ('extra', 411),
#  ('activate', 411),
#  ('far', 411),
#  ('already', 411),
#  ('leg', 410),
#  ('supplement', 410),
#  ('company', 410),
#  ('cup', 409),
#  ('remedy', 409),
#  ('organic', 409),
#  ('present', 407),
#  ('against', 407),
#  ('button', 404),
#  ('taste', 404),
#  ('essential', 404),
#  ('wear', 403),
#  ('break', 400),
#  ('education', 400),
#  ('believe', 400),
#  ('stomach', 399),
#  ('idea', 399),
#  ('fresco', 398),
#  ('kind', 398),
#  ('expert', 398),
#  ('black', 397),
#  ('short', 397),
#  ('lifestyle', 396),
#  ('art', 395),
#  ('damage', 395),
#  ('addition', 395),
#  ('traditional', 395),
#  ('youve', 394),
#  ('note', 394),
#  ('reach', 394),
#  ('pavement', 393),
#  ('unique', 392),
#  ('ive', 389),
#  ('location', 389),
#  ('factor', 389),
#  ('holeinthewall', 388),
#  ('everyone', 388),
#  ('island', 387),
#  ('although', 387),
#  ('deep', 386),
#  ('diabetes', 384),
#  ('theres', 383),
#  ('selection', 382),
#  ('question', 382),
#  ('heat', 382),
#  ('publish', 381),
#  ('15', 380),
#  ('clean', 379),
#  ('instead', 379),
#  ('couple', 378),
#  ('clinical', 378),
#  ('yoga', 376),
#  ('buy', 376),
#  ('maintain', 376),
#  ('customer', 375),
#  ('video', 374),
#  ('challenge', 374),
#  ('8', 374),
#  ('beauty', 372),
#  ('today', 372),
#  ('piece', 371),
#  ('across', 371),
#  ('pick', 370),
#  ('regular', 370),
#  ('sometimes', 370),
#  ('explain', 370),
#  ('lung', 370),
#  ('complete', 369),
#  ('liver', 367),
#  ('cook', 366),
#  ('sit', 366),
#  ('property', 366),
#  ('animal', 365),
#  ('technology', 365),
#  ('cheese', 364),
#  ('american', 363),
#  ('centre', 362),
#  ('promote', 362),
#  ('vegan', 359),
#  ('pay', 359),
#  ('adult', 359),
#  ('program', 359),
#  ('general', 359),
#  ('meet', 359),
#  ('bay', 358),
#  ('fun', 358),
#  ('whats', 358),
#  ('remove', 358),
#  ('nutrient', 358),
#  ('nutrition', 357),
#  ('development', 357),
#  ('cover', 356),
#  ('kidney', 354),
#  ('100', 354),
#  ('environment', 353),
#  ('fill', 352),
#  ('clear', 350),
#  ('review', 349),
#  ('popular', 349),
#  ('article', 349),
#  ('fit', 349),
#  ('chicken', 348),
#  ('dry', 347),
#  ('matter', 346),
#  ('credit', 346),
#  ('fish', 345),
#  ('wont', 345),
#  ('guy', 344),
#  ('link', 344),
#  ('half', 344),
#  ('tai', 343),
#  ('certain', 343),
#  ('party', 342),
#  ('antioxidant', 342),
#  ('chance', 341),
#  ('date', 341),
#  ('role', 341),
#  ('teach', 340),
#  ('international', 340),
#  ('delicious', 339),
#  ('plus', 339),
#  ('massage', 339),
#  ('involve', 339),
#  ('7', 339),
#  ('photo', 338),
#  ('kongs', 338),
#  ('e', 337),
#  ('depression', 337),
#  ('several', 337),
#  ('medication', 337),
#  ('consume', 337),
#  ('associate', 337),
#  ('chronic', 337),
#  ('mother', 336),
#  ('various', 336),
#  ('bit', 335),
#  ('fast', 335),
#  ('rest', 335),
#  ('hit', 334),
#  ('parent', 334),
#  ('12', 334),
#  ('past', 334),
#  ('classic', 333),
#  ('yet', 332),
#  ('above', 332),
#  ('expect', 331),
#  ('attention', 331),
#  ('specific', 331),
#  ('anything', 330),
#  ('definitely', 330),
#  ('hospital', 330),
#  ('fiber', 329),
#  ('researcher', 329),
#  ('vegetable', 328),
#  ('hormone', 328),
#  ('stand', 328),
#  ('g', 328),
#  ('item', 327),
#  ('behind', 326),
#  ('d', 326),
#  ('national', 326),
#  ('rich', 326),
#  ('attack', 325),
#  ('among', 325),
#  ('safe', 323),
#  ('salt', 322),
#  ('difficult', 321),
#  ('goal', 321),
#  ('simply', 320),
#  ('market', 320),
#  ('positive', 320),
#  ('opportunity', 320),
#  ('story', 320),
#  ('office', 318),
#  ('below', 318),
#  ('snack', 317),
#  ('raise', 317),
#  ('boost', 317),
#  ('main', 317),
#  ('either', 317),
#  ('weve', 316),
#  ('meditation', 316),
#  ('size', 316),
#  ('ensure', 316),
#  ('lunch', 315),
#  ('man', 315),
#  ('hear', 315),
#  ('50', 315),
#  ('death', 315),
#  ('md', 314),
#  ('worth', 314),
#  ('almost', 312),
#  ('save', 312),
#  ('bone', 312),
#  ('breakfast', 311),
#  ('session', 311),
#  ('honey', 311),
#  ('impact', 310),
#  ('cool', 309),
#  ('bed', 309),
#  ('variety', 308),
#  ('felt', 308),
#  ('journey', 307),
#  ('busy', 307),
#  ('normal', 307),
#  ('kid', 306),
#  ('breast', 306),
#  ('gym', 305),
#  ('suffer', 305),
#  ('enter', 305),
#  ('explore', 304),
#  ('action', 303),
#  ('probably', 302),
#  ('kowloon', 302),
#  ('account', 302),
#  ('season', 302),
#  ('google', 301),
#  ('watch', 301),
#  ('weekend', 300),
#  ('click', 300),
#  ('cream', 299),
#  ('dinner', 299),
#  ('access', 299),
#  ('throughout', 299),
#  ('production', 298),
#  ('easily', 298),
#  ('business', 298),
#  ('email', 297),
#  ('protect', 297),
#  ('limit', 297),
#  ('address', 297),
#  ('author', 296),
#  ('peace', 296),
#  ('floor', 295),
#  ('quite', 295),
#  ('feeling', 295),
#  ('ready', 294),
#  ('nothing', 294),
#  ('rate', 294),
#  ('future', 293),
#  ('cholesterol', 291),
#  ('movement', 291),
#  ('mix', 290),
#  ('fashion', 289),
#  ('sport', 289),
#  ('miss', 288),
#  ('music', 288),
#  ('technique', 288),
#  ('burn', 288),
#  ('later', 287),
#  ('material', 287),
#  ('notice', 287),
#  ('arm', 285),
#  ('advice', 285),
#  ('shes', 284),
#  ('flow', 283),
#  ('sun', 282),
#  ('client', 282),
#  ('ability', 282),
#  ('pretty', 281),
#  ('bottle', 281),
#  ('detail', 281),
#  ('release', 281),
#  ('dog', 281),
#  ('similar', 281),
#  ('select', 281),
#  ('salad', 280),
#  ('train', 280),
#  ('trial', 280),
#  ('method', 280),
#  ('discount', 279),
#  ('sunday', 279),
#  ('pregnancy', 278),
#  ('plenty', 278),
#  ('true', 278),
#  ('approach', 278),
#  ('difference', 277),
#  ('privacy', 277),
#  ('routine', 277),
#  ('pack', 276),
#  ('occur', 276),
#  ('inside', 276),
#  ('gain', 276),
#  ('wait', 275),
#  ('park', 275),
#  ('carry', 275),
#  ('outside', 274),
#  ('quickly', 274),
#  ('joint', 274),
#  ('china', 274),
#  ('2017', 273),
#  ('serious', 273),
#  ('code', 272),
#  ('cocktail', 271),
#  ('growth', 271),
#  ('core', 271),
#  ('six', 270),
#  ('seed', 270),
#  ('power', 270),
#  ('send', 270),
#  ('habit', 269),
#  ('learning', 269),
#  ('fall', 269),
#  ('m', 269),
#  ('b', 269),
#  ('nature', 269),
#  ('sound', 268),
#  ('science', 268),
#  ('collection', 268),
#  ('town', 267),
#  ('fan', 267),
#  ('global', 267),
#  ('lift', 267),
#  ('soup', 267),
#  ('inflammation', 266),
#  ('director', 266),
#  ('evidence', 266),
#  ('major', 266),
#  ('worry', 265),
#  ('asia', 265),
#  ('combine', 265),
#  ('plastic', 264),
#  ('manage', 264),
#  ('dark', 264),
#  ('join', 264),
#  ('fine', 264),
#  ('hk', 264),
#  ('glass', 263),
#  ('deliver', 263),
#  ('bag', 262),
#  ('star', 262),
#  ('appear', 262),
#  ('bacteria', 262),
#  ('journal', 261),
#  ('job', 261),
#  ('page', 261),
#  ('achieve', 261),
#  ('relate', 261),
#  ('hip', 260),
#  ('beautiful', 260),
#  ('perform', 260),
#  ('word', 260),
#  ('lemon', 259),
#  ('tsui', 259),
#  ('million', 259),
#  ('allergy', 259),
#  ('raw', 259),
#  ('moment', 259),
#  ('decide', 257),
#  ('building', 257),
#  ('illness', 257),
#  ('quick', 256),
#  ('delivery', 256),
#  ('birth', 255),
#  ('myself', 255),
#  ('straight', 255),
#  ('rice', 254),
#  ('drive', 254),
#  ('enhance', 254),
#  ('wide', 253),
#  ('prepare', 253),
#  ('remember', 252),
#  ('intake', 252),
#  ('dress', 252),
#  ('living', 252),
#  ('sha', 251),
#  ('hotel', 251),
#  ('40', 251),
#  ('award', 250),
#  ('box', 250),
#  ('stage', 250),
#  ('potential', 250),
#  ('depend', 250),
#  ('history', 250),
#  ('sell', 249),
#  ('fight', 249),
#  ('strength', 249),
#  ('kitchen', 248),
#  ('touch', 248),
#  ('soon', 248),
#  ('table', 247),
#  ('soft', 246),
#  ('hike', 246),
#  ('value', 245),
#  ('thanks', 244),
#  ('neck', 244),
#  ('response', 244),
#  ('warm', 244),
#  ('concern', 243),
#  ('accept', 243),
#  ('culture', 243),
#  ('purpose', 243),
#  ('sense', 243),
#  ('wedding', 242),
#  ('alternative', 242),
#  ('standard', 242),
#  ('iron', 241),
#  ('lack', 241),
#  ('modern', 241),
#  ('compare', 240),
#  ('catch', 240),
#  ('anyone', 239),
#  ('relax', 239),
#  ('color', 239),
#  ('sai', 238),
#  ('burger', 238),
#  ('bite', 237),
#  ('shoulder', 237),
#  ('tissue', 237),
#  ('active', 237),
#  ('drop', 236),
#  ('apple', 236),
#  ('programme', 236),
#  ('aim', 236),
#  ('flavour', 235),
#  ('arent', 235),
#  ('recent', 235),
#  ('project', 235),
#  ('chemical', 235),
#  ('severe', 235),
#  ('calcium', 235),
#  ('phone', 234),
#  ('naturally', 234),
#  ('pair', 233),
#  ('coconut', 233),
#  ('further', 233),
#  ('knee', 232),
#  ('beef', 232),
#  ('super', 232),
#  ('return', 232),
#  ('9', 232),
#  ('practitioner', 232),
#  ('act', 232),
#  ('chai', 231),
#  ('york', 231),
#  ('single', 231),
#  ('25', 230),
#  ('11', 230),
#  ('remain', 230),
#  ('nail', 229),
#  ('chocolate', 229),
#  ('middle', 229),
#  ('everyday', 229),
#  ('cannot', 229),
#  ('brunch', 227),
#  ('teacher', 227),
#  ('cost', 227),
#  ('overall', 227),
#  ('heal', 227),
#  ('rise', 227),
#  ('mineral', 226),
#  ('wash', 226),
#  ('june', 226),
#  ('seek', 226),
#  ...]

# %%
# These words only appear <5 times throughout the entire corpus, 
# they are not able to influence the LDA in a meaningful way, 
# so they are removed to aid in computation
def filterRareWords(doc):
    return [x for x in doc if frequency[x] > 4]

corpus["text_lem"] = corpus["text_lem"].apply(filterRareWords)
# Out:
# /home/rebootaihk/anaconda3/envs/text/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getRankedFrequency(corpus)
# Out:
# [('the', 75229),
#  ('and', 55626),
#  ('be', 50469),
#  ('to', 48533),
#  ('a', 46750),
#  ('of', 41707),
#  ('in', 28074),
#  ('for', 19283),
#  ('you', 18483),
#  ('it', 18305),
#  ('that', 15767),
#  ('your', 15561),
#  ('with', 14878),
#  ('have', 13391),
#  ('on', 11718),
#  ('or', 10127),
#  ('can', 9979),
#  ('this', 9096),
#  ('i', 8167),
#  ('from', 7900),
#  ('at', 6705),
#  ('we', 6248),
#  ('by', 5948),
#  ('but', 5862),
#  ('not', 5670),
#  ('if', 5560),
#  ('more', 5383),
#  ('an', 5374),
#  ('all', 5119),
#  ('also', 4876),
#  ('will', 4860),
#  ('hong', 4813),
#  ('say', 4788),
#  ('our', 4762),
#  ('use', 4730),
#  ('do', 4572),
#  ('get', 4529),
#  ('make', 4497),
#  ('one', 4493),
#  ('up', 4051),
#  ('so', 4023),
#  ('kong', 4011),
#  ('when', 3924),
#  ('about', 3772),
#  ('which', 3726),
#  ('out', 3682),
#  ('time', 3641),
#  ('my', 3628),
#  ('help', 3572),
#  ('they', 3570),
#  ('their', 3440),
#  ('health', 3399),
#  ('like', 3337),
#  ('take', 3332),
#  ('body', 3248),
#  ('there', 3238),
#  ('some', 3188),
#  ('may', 3086),
#  ('her', 3054),
#  ('people', 3006),
#  ('he', 2983),
#  ('day', 2953),
#  ('who', 2918),
#  ('go', 2895),
#  ('just', 2846),
#  ('find', 2697),
#  ('she', 2645),
#  ('other', 2628),
#  ('good', 2609),
#  ('food', 2605),
#  ('how', 2483),
#  ('these', 2435),
#  ('than', 2416),
#  ('work', 2414),
#  ('what', 2397),
#  ('most', 2374),
#  ('youre', 2340),
#  ('need', 2327),
#  ('know', 2309),
#  ('look', 2280),
#  ('include', 2247),
#  ('new', 2211),
#  ('after', 2197),
#  ('any', 2127),
#  ('into', 2104),
#  ('year', 2070),
#  ('no', 2065),
#  ('his', 2049),
#  ('life', 2037),
#  ('even', 2030),
#  ('way', 2019),
#  ('best', 2004),
#  ('well', 1988),
#  ('many', 1958),
#  ('them', 1944),
#  ('only', 1900),
#  ('such', 1865),
#  ('offer', 1849),
#  ('want', 1810),
#  ('u', 1784),
#  ('feel', 1780),
#  ('eat', 1764),
#  ('come', 1763),
#  ('cause', 1751),
#  ('while', 1738),
#  ('skin', 1716),
#  ('because', 1715),
#  ('dont', 1676),
#  ('high', 1662),
#  ('start', 1646),
#  ('back', 1634),
#  ('much', 1634),
#  ('me', 1620),
#  ('as', 1617),
#  ('over', 1608),
#  ('keep', 1595),
#  ('should', 1584),
#  ('here', 1565),
#  ('through', 1552),
#  ('image', 1542),
#  ('see', 1532),
#  ('first', 1528),
#  ('give', 1517),
#  ('experience', 1511),
#  ('before', 1499),
#  ('product', 1484),
#  ('study', 1483),
#  ('woman', 1465),
#  ('then', 1459),
#  ('try', 1445),
#  ('healthy', 1444),
#  ('every', 1423),
#  ('two', 1417),
#  ('water', 1366),
#  ('great', 1349),
#  ('think', 1349),
#  ('blood', 1346),
#  ('disease', 1340),
#  ('city', 1335),
#  ('those', 1332),
#  ('where', 1315),
#  ('provide', 1315),
#  ('thing', 1309),
#  ('drink', 1309),
#  ('diet', 1308),
#  ('very', 1306),
#  ('right', 1305),
#  ('pain', 1304),
#  ('too', 1289),
#  ('change', 1287),
#  ('sleep', 1281),
#  ('world', 1260),
#  ('down', 1255),
#  ('service', 1220),
#  ('level', 1217),
#  ('show', 1215),
#  ('risk', 1208),
#  ('add', 1204),
#  ('now', 1201),
#  ('weight', 1195),
#  ('love', 1188),
#  ('place', 1183),
#  ('home', 1183),
#  ('during', 1168),
#  ('treatment', 1152),
#  ('cancer', 1143),
#  ('oil', 1130),
#  ('long', 1128),
#  ('learn', 1128),
#  ('off', 1126),
#  ('support', 1114),
#  ('could', 1110),
#  ('information', 1110),
#  ('around', 1105),
#  ('close', 1089),
#  ('fat', 1076),
#  ('would', 1074),
#  ('little', 1054),
#  ('exercise', 1054),
#  ('restaurant', 1050),
#  ('part', 1050),
#  ('few', 1044),
#  ('hour', 1041),
#  ('between', 1040),
#  ('child', 1037),
#  ('never', 1036),
#  ('shop', 1035),
#  ('result', 1035),
#  ('really', 1033),
#  ('sure', 1032),
#  ('both', 1031),
#  ('effect', 1021),
#  ('spot', 1018),
#  ('increase', 1003),
#  ('bar', 1002),
#  ('week', 992),
#  ('via', 983),
#  ('heart', 979),
#  ('thats', 978),
#  ('2', 977),
#  ('problem', 977),
#  ('reduce', 973),
#  ('vitamin', 970),
#  ('hair', 963),
#  ('patient', 962),
#  ('still', 961),
#  ('courtesy', 957),
#  ('each', 956),
#  ('call', 952),
#  ('care', 951),
#  ('1', 948),
#  ('student', 945),
#  ('different', 944),
#  ('system', 929),
#  ('research', 927),
#  ('event', 924),
#  ('improve', 920),
#  ('dr', 917),
#  ('something', 913),
#  ('without', 910),
#  ('natural', 910),
#  ('head', 904),
#  ('family', 904),
#  ('low', 898),
#  ('medical', 896),
#  ('street', 893),
#  ('group', 893),
#  ('road', 888),
#  ('lead', 888),
#  ('age', 887),
#  ('often', 886),
#  ('doctor', 882),
#  ('always', 882),
#  ('might', 881),
#  ('open', 881),
#  ('become', 881),
#  ('important', 879),
#  ('tell', 876),
#  ('benefit', 874),
#  ('mean', 873),
#  ('symptom', 864),
#  ('own', 860),
#  ('live', 851),
#  ('area', 846),
#  ('sassy', 845),
#  ('special', 845),
#  ('three', 841),
#  ('why', 837),
#  ('easy', 835),
#  ('lot', 833),
#  ('stress', 832),
#  ('medicine', 831),
#  ('set', 827),
#  ('youll', 823),
#  ('protein', 815),
#  ('same', 801),
#  ('course', 795),
#  ('person', 793),
#  ('3', 791),
#  ('10', 789),
#  ('control', 788),
#  ('top', 787),
#  ('type', 787),
#  ('hand', 787),
#  ('accord', 786),
#  ('small', 786),
#  ('condition', 779),
#  ('share', 775),
#  ('treat', 773),
#  ('muscle', 771),
#  ('perfect', 769),
#  ('free', 767),
#  ('site', 766),
#  ('check', 755),
#  ('bring', 755),
#  ('available', 754),
#  ('month', 753),
#  ('im', 751),
#  ('another', 750),
#  ('big', 749),
#  ('order', 749),
#  ('create', 748),
#  ('point', 746),
#  ('contain', 742),
#  ('tea', 739),
#  ('follow', 739),
#  ('quality', 738),
#  ('girl', 734),
#  ('university', 730),
#  ('sugar', 728),
#  ('minute', 718),
#  ('leave', 718),
#  ('option', 716),
#  ('however', 713),
#  ('put', 712),
#  ('friend', 709),
#  ('side', 709),
#  ('away', 706),
#  ('form', 706),
#  ('meal', 705),
#  ('sex', 703),
#  ('modal', 702),
#  ('chinese', 700),
#  ('common', 698),
#  ('pound', 694),
#  ('daily', 694),
#  ('night', 689),
#  ('ask', 688),
#  ('let', 688),
#  ('ingredient', 680),
#  ('key', 679),
#  ('per', 678),
#  ('serve', 676),
#  ('guide', 676),
#  ('since', 668),
#  ('yourself', 667),
#  ('end', 663),
#  ('less', 662),
#  ('enjoy', 662),
#  ('content', 659),
#  ('central', 655),
#  ('recommend', 654),
#  ('whether', 653),
#  ('mind', 651),
#  ('lose', 650),
#  ('old', 650),
#  ('face', 649),
#  ('develop', 648),
#  ('book', 645),
#  ('amount', 644),
#  ('run', 641),
#  ('design', 641),
#  ('under', 640),
#  ('fruit', 639),
#  ('next', 638),
#  ('partner', 636),
#  ('eye', 636),
#  ('him', 633),
#  ('full', 633),
#  ('store', 633),
#  ('number', 632),
#  ('process', 629),
#  ('move', 627),
#  ('talk', 625),
#  ('5', 620),
#  ('activity', 620),
#  ('actually', 620),
#  ('once', 619),
#  ('baby', 613),
#  ('happy', 612),
#  ('along', 612),
#  ('enough', 608),
#  ('last', 607),
#  ('turn', 606),
#  ('cell', 605),
#  ('issue', 604),
#  ('energy', 601),
#  ('men', 599),
#  ('fresh', 598),
#  ('loss', 598),
#  ('choose', 598),
#  ('search', 597),
#  ('range', 597),
#  ('data', 595),
#  ('especially', 591),
#  ('plan', 589),
#  ('until', 586),
#  ('allow', 586),
#  ('reason', 583),
#  ('test', 581),
#  ('case', 580),
#  ('mental', 578),
#  ('prevent', 578),
#  ('hot', 572),
#  ('website', 572),
#  ('stay', 571),
#  ('cant', 570),
#  ('walk', 568),
#  ('hard', 567),
#  ('continue', 565),
#  ('feature', 564),
#  ('facebook', 563),
#  ('practice', 563),
#  ('personal', 560),
#  ('secret', 558),
#  ('light', 557),
#  ('source', 557),
#  ('understand', 555),
#  ('truly', 552),
#  ('sign', 552),
#  ('public', 542),
#  ('state', 540),
#  ('receive', 539),
#  ('doesnt', 537),
#  ('wine', 536),
#  ('affect', 536),
#  ('foot', 535),
#  ('online', 535),
#  ('read', 534),
#  ('bad', 529),
#  ('4', 526),
#  ('term', 526),
#  ('press', 524),
#  ('wan', 521),
#  ('stop', 520),
#  ('report', 520),
#  ('avoid', 519),
#  ('base', 516),
#  ('play', 516),
#  ('country', 516),
#  ('calorie', 514),
#  ('grow', 513),
#  ('able', 513),
#  ('school', 512),
#  ('green', 511),
#  ('large', 511),
#  ('others', 510),
#  ('whole', 508),
#  ('medium', 508),
#  ('news', 508),
#  ('visit', 503),
#  ('al', 502),
#  ('happen', 502),
#  ('usually', 502),
#  ('local', 502),
#  ('tip', 500),
#  ('simple', 500),
#  ('focus', 499),
#  ('strong', 498),
#  ('workout', 497),
#  ('ever', 497),
#  ('name', 497),
#  ('social', 496),
#  ('cold', 496),
#  ('policy', 496),
#  ('house', 495),
#  ('early', 494),
#  ('physical', 493),
#  ('menu', 492),
#  ('consider', 492),
#  ('brain', 491),
#  ('post', 491),
#  ('list', 490),
#  ('20', 490),
#  ('2018', 488),
#  ('goto', 487),
#  ('everything', 487),
#  ('spend', 486),
#  ('dish', 484),
#  ('though', 484),
#  ('style', 482),
#  ('drug', 482),
#  ('beach', 481),
#  ('professional', 481),
#  ('example', 481),
#  ('young', 479),
#  ('please', 479),
#  ('human', 477),
#  ('fact', 475),
#  ('effective', 475),
#  ('price', 474),
#  ('four', 474),
#  ('second', 474),
#  ('position', 473),
#  ('together', 472),
#  ('choice', 471),
#  ('coffee', 467),
#  ('acid', 467),
#  ('due', 466),
#  ('write', 464),
#  ('morning', 464),
#  ('c', 464),
#  ('team', 463),
#  ('egg', 462),
#  ('brand', 462),
#  ('instagram', 461),
#  ('pressure', 461),
#  ('suggest', 460),
#  ('white', 460),
#  ('build', 459),
#  ('isnt', 458),
#  ('real', 458),
#  ('30', 458),
#  ('possible', 458),
#  ('travel', 457),
#  ('room', 456),
#  ('step', 455),
#  ('center', 455),
#  ('acupuncture', 452),
#  ('class', 451),
#  ('infection', 450),
#  ('theyre', 449),
#  ('favourite', 448),
#  ('didnt', 447),
#  ('balance', 447),
#  ('seem', 446),
#  ('must', 446),
#  ('meat', 445),
#  ('juice', 445),
#  ('hold', 445),
#  ('6', 444),
#  ('likely', 442),
#  ('apply', 441),
#  ('red', 441),
#  ('relationship', 441),
#  ('summer', 440),
#  ('least', 438),
#  ('training', 437),
#  ('view', 437),
#  ('fitness', 436),
#  ('require', 436),
#  ('late', 436),
#  ('member', 434),
#  ('sweet', 433),
#  ('five', 432),
#  ('disorder', 432),
#  ('window', 432),
#  ('therapy', 432),
#  ('line', 432),
#  ('cooky', 431),
#  ('begin', 431),
#  ('individual', 431),
#  ('contact', 430),
#  ('immune', 430),
#  ('milk', 428),
#  ('produce', 427),
#  ('cut', 426),
#  ('space', 425),
#  ('period', 425),
#  ('percent', 424),
#  ('again', 424),
#  ('gift', 421),
#  ('within', 421),
#  ('beer', 419),
#  ('function', 418),
#  ('escape', 417),
#  ('air', 415),
#  ('community', 414),
#  ('professor', 414),
#  ('anxiety', 413),
#  ('someone', 413),
#  ('deal', 412),
#  ('extra', 411),
#  ('activate', 411),
#  ('far', 411),
#  ('already', 411),
#  ('leg', 410),
#  ('supplement', 410),
#  ('company', 410),
#  ('cup', 409),
#  ('remedy', 409),
#  ('organic', 409),
#  ('present', 407),
#  ('against', 407),
#  ('button', 404),
#  ('taste', 404),
#  ('essential', 404),
#  ('wear', 403),
#  ('break', 400),
#  ('education', 400),
#  ('believe', 400),
#  ('stomach', 399),
#  ('idea', 399),
#  ('fresco', 398),
#  ('kind', 398),
#  ('expert', 398),
#  ('black', 397),
#  ('short', 397),
#  ('lifestyle', 396),
#  ('art', 395),
#  ('damage', 395),
#  ('addition', 395),
#  ('traditional', 395),
#  ('youve', 394),
#  ('note', 394),
#  ('reach', 394),
#  ('pavement', 393),
#  ('unique', 392),
#  ('ive', 389),
#  ('location', 389),
#  ('factor', 389),
#  ('holeinthewall', 388),
#  ('everyone', 388),
#  ('island', 387),
#  ('although', 387),
#  ('deep', 386),
#  ('diabetes', 384),
#  ('theres', 383),
#  ('selection', 382),
#  ('question', 382),
#  ('heat', 382),
#  ('publish', 381),
#  ('15', 380),
#  ('clean', 379),
#  ('instead', 379),
#  ('couple', 378),
#  ('clinical', 378),
#  ('yoga', 376),
#  ('buy', 376),
#  ('maintain', 376),
#  ('customer', 375),
#  ('video', 374),
#  ('challenge', 374),
#  ('8', 374),
#  ('beauty', 372),
#  ('today', 372),
#  ('piece', 371),
#  ('across', 371),
#  ('pick', 370),
#  ('regular', 370),
#  ('sometimes', 370),
#  ('explain', 370),
#  ('lung', 370),
#  ('complete', 369),
#  ('liver', 367),
#  ('cook', 366),
#  ('sit', 366),
#  ('property', 366),
#  ('animal', 365),
#  ('technology', 365),
#  ('cheese', 364),
#  ('american', 363),
#  ('centre', 362),
#  ('promote', 362),
#  ('vegan', 359),
#  ('pay', 359),
#  ('adult', 359),
#  ('program', 359),
#  ('general', 359),
#  ('meet', 359),
#  ('bay', 358),
#  ('fun', 358),
#  ('whats', 358),
#  ('remove', 358),
#  ('nutrient', 358),
#  ('nutrition', 357),
#  ('development', 357),
#  ('cover', 356),
#  ('kidney', 354),
#  ('100', 354),
#  ('environment', 353),
#  ('fill', 352),
#  ('clear', 350),
#  ('review', 349),
#  ('popular', 349),
#  ('article', 349),
#  ('fit', 349),
#  ('chicken', 348),
#  ('dry', 347),
#  ('matter', 346),
#  ('credit', 346),
#  ('fish', 345),
#  ('wont', 345),
#  ('guy', 344),
#  ('link', 344),
#  ('half', 344),
#  ('tai', 343),
#  ('certain', 343),
#  ('party', 342),
#  ('antioxidant', 342),
#  ('chance', 341),
#  ('date', 341),
#  ('role', 341),
#  ('teach', 340),
#  ('international', 340),
#  ('delicious', 339),
#  ('plus', 339),
#  ('massage', 339),
#  ('involve', 339),
#  ('7', 339),
#  ('photo', 338),
#  ('kongs', 338),
#  ('e', 337),
#  ('depression', 337),
#  ('several', 337),
#  ('medication', 337),
#  ('consume', 337),
#  ('associate', 337),
#  ('chronic', 337),
#  ('mother', 336),
#  ('various', 336),
#  ('bit', 335),
#  ('fast', 335),
#  ('rest', 335),
#  ('hit', 334),
#  ('parent', 334),
#  ('12', 334),
#  ('past', 334),
#  ('classic', 333),
#  ('yet', 332),
#  ('above', 332),
#  ('expect', 331),
#  ('attention', 331),
#  ('specific', 331),
#  ('anything', 330),
#  ('definitely', 330),
#  ('hospital', 330),
#  ('fiber', 329),
#  ('researcher', 329),
#  ('vegetable', 328),
#  ('hormone', 328),
#  ('stand', 328),
#  ('g', 328),
#  ('item', 327),
#  ('behind', 326),
#  ('d', 326),
#  ('national', 326),
#  ('rich', 326),
#  ('attack', 325),
#  ('among', 325),
#  ('safe', 323),
#  ('salt', 322),
#  ('difficult', 321),
#  ('goal', 321),
#  ('simply', 320),
#  ('market', 320),
#  ('positive', 320),
#  ('opportunity', 320),
#  ('story', 320),
#  ('office', 318),
#  ('below', 318),
#  ('snack', 317),
#  ('raise', 317),
#  ('boost', 317),
#  ('main', 317),
#  ('either', 317),
#  ('weve', 316),
#  ('meditation', 316),
#  ('size', 316),
#  ('ensure', 316),
#  ('lunch', 315),
#  ('man', 315),
#  ('hear', 315),
#  ('50', 315),
#  ('death', 315),
#  ('md', 314),
#  ('worth', 314),
#  ('almost', 312),
#  ('save', 312),
#  ('bone', 312),
#  ('breakfast', 311),
#  ('session', 311),
#  ('honey', 311),
#  ('impact', 310),
#  ('cool', 309),
#  ('bed', 309),
#  ('variety', 308),
#  ('felt', 308),
#  ('journey', 307),
#  ('busy', 307),
#  ('normal', 307),
#  ('kid', 306),
#  ('breast', 306),
#  ('gym', 305),
#  ('suffer', 305),
#  ('enter', 305),
#  ('explore', 304),
#  ('action', 303),
#  ('probably', 302),
#  ('kowloon', 302),
#  ('account', 302),
#  ('season', 302),
#  ('google', 301),
#  ('watch', 301),
#  ('weekend', 300),
#  ('click', 300),
#  ('cream', 299),
#  ('dinner', 299),
#  ('access', 299),
#  ('throughout', 299),
#  ('production', 298),
#  ('easily', 298),
#  ('business', 298),
#  ('email', 297),
#  ('protect', 297),
#  ('limit', 297),
#  ('address', 297),
#  ('author', 296),
#  ('peace', 296),
#  ('floor', 295),
#  ('quite', 295),
#  ('feeling', 295),
#  ('ready', 294),
#  ('nothing', 294),
#  ('rate', 294),
#  ('future', 293),
#  ('cholesterol', 291),
#  ('movement', 291),
#  ('mix', 290),
#  ('fashion', 289),
#  ('sport', 289),
#  ('miss', 288),
#  ('music', 288),
#  ('technique', 288),
#  ('burn', 288),
#  ('later', 287),
#  ('material', 287),
#  ('notice', 287),
#  ('arm', 285),
#  ('advice', 285),
#  ('shes', 284),
#  ('flow', 283),
#  ('sun', 282),
#  ('client', 282),
#  ('ability', 282),
#  ('pretty', 281),
#  ('bottle', 281),
#  ('detail', 281),
#  ('release', 281),
#  ('dog', 281),
#  ('similar', 281),
#  ('select', 281),
#  ('salad', 280),
#  ('train', 280),
#  ('trial', 280),
#  ('method', 280),
#  ('discount', 279),
#  ('sunday', 279),
#  ('pregnancy', 278),
#  ('plenty', 278),
#  ('true', 278),
#  ('approach', 278),
#  ('difference', 277),
#  ('privacy', 277),
#  ('routine', 277),
#  ('pack', 276),
#  ('occur', 276),
#  ('inside', 276),
#  ('gain', 276),
#  ('wait', 275),
#  ('park', 275),
#  ('carry', 275),
#  ('outside', 274),
#  ('quickly', 274),
#  ('joint', 274),
#  ('china', 274),
#  ('2017', 273),
#  ('serious', 273),
#  ('code', 272),
#  ('cocktail', 271),
#  ('growth', 271),
#  ('core', 271),
#  ('six', 270),
#  ('seed', 270),
#  ('power', 270),
#  ('send', 270),
#  ('habit', 269),
#  ('learning', 269),
#  ('fall', 269),
#  ('m', 269),
#  ('b', 269),
#  ('nature', 269),
#  ('sound', 268),
#  ('science', 268),
#  ('collection', 268),
#  ('town', 267),
#  ('fan', 267),
#  ('global', 267),
#  ('lift', 267),
#  ('soup', 267),
#  ('inflammation', 266),
#  ('director', 266),
#  ('evidence', 266),
#  ('major', 266),
#  ('worry', 265),
#  ('asia', 265),
#  ('combine', 265),
#  ('plastic', 264),
#  ('manage', 264),
#  ('dark', 264),
#  ('join', 264),
#  ('fine', 264),
#  ('hk', 264),
#  ('glass', 263),
#  ('deliver', 263),
#  ('bag', 262),
#  ('star', 262),
#  ('appear', 262),
#  ('bacteria', 262),
#  ('journal', 261),
#  ('job', 261),
#  ('page', 261),
#  ('achieve', 261),
#  ('relate', 261),
#  ('hip', 260),
#  ('beautiful', 260),
#  ('perform', 260),
#  ('word', 260),
#  ('lemon', 259),
#  ('tsui', 259),
#  ('million', 259),
#  ('allergy', 259),
#  ('raw', 259),
#  ('moment', 259),
#  ('decide', 257),
#  ('building', 257),
#  ('illness', 257),
#  ('quick', 256),
#  ('delivery', 256),
#  ('birth', 255),
#  ('myself', 255),
#  ('straight', 255),
#  ('rice', 254),
#  ('drive', 254),
#  ('enhance', 254),
#  ('wide', 253),
#  ('prepare', 253),
#  ('remember', 252),
#  ('intake', 252),
#  ('dress', 252),
#  ('living', 252),
#  ('sha', 251),
#  ('hotel', 251),
#  ('40', 251),
#  ('award', 250),
#  ('box', 250),
#  ('stage', 250),
#  ('potential', 250),
#  ('depend', 250),
#  ('history', 250),
#  ('sell', 249),
#  ('fight', 249),
#  ('strength', 249),
#  ('kitchen', 248),
#  ('touch', 248),
#  ('soon', 248),
#  ('table', 247),
#  ('soft', 246),
#  ('hike', 246),
#  ('value', 245),
#  ('thanks', 244),
#  ('neck', 244),
#  ('response', 244),
#  ('warm', 244),
#  ('concern', 243),
#  ('accept', 243),
#  ('culture', 243),
#  ('purpose', 243),
#  ('sense', 243),
#  ('wedding', 242),
#  ('alternative', 242),
#  ('standard', 242),
#  ('iron', 241),
#  ('lack', 241),
#  ('modern', 241),
#  ('compare', 240),
#  ('catch', 240),
#  ('anyone', 239),
#  ('relax', 239),
#  ('color', 239),
#  ('sai', 238),
#  ('burger', 238),
#  ('bite', 237),
#  ('shoulder', 237),
#  ('tissue', 237),
#  ('active', 237),
#  ('drop', 236),
#  ('apple', 236),
#  ('programme', 236),
#  ('aim', 236),
#  ('flavour', 235),
#  ('arent', 235),
#  ('recent', 235),
#  ('project', 235),
#  ('chemical', 235),
#  ('severe', 235),
#  ('calcium', 235),
#  ('phone', 234),
#  ('naturally', 234),
#  ('pair', 233),
#  ('coconut', 233),
#  ('further', 233),
#  ('knee', 232),
#  ('beef', 232),
#  ('super', 232),
#  ('return', 232),
#  ('9', 232),
#  ('practitioner', 232),
#  ('act', 232),
#  ('chai', 231),
#  ('york', 231),
#  ('single', 231),
#  ('25', 230),
#  ('11', 230),
#  ('remain', 230),
#  ('nail', 229),
#  ('chocolate', 229),
#  ('middle', 229),
#  ('everyday', 229),
#  ('cannot', 229),
#  ('brunch', 227),
#  ('teacher', 227),
#  ('cost', 227),
#  ('overall', 227),
#  ('heal', 227),
#  ('rise', 227),
#  ('mineral', 226),
#  ('wash', 226),
#  ('june', 226),
#  ('seek', 226),
#  ...]

# %%
# Using wordcloud STOPWORDS, a fairly extenive stopword list
def filterStopWords(doc):
    return [x for x in doc if x not in wordcloud.STOPWORDS]

corpus["text_lem"] = corpus["text_lem"].apply(filterStopWords)
# Out:
# /home/rebootaihk/anaconda3/envs/text/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
dictionary = corpora.Dictionary(corpus["text_lem"].values)
print(dictionary)
for i in dictionary.keys()[:5]:
    print()
    print(i)
    print(dictionary.get(i))
# Out:
# Dictionary(13515 unique tokens: ['official', 'name', 'codonopsis', 'radix', 'english']...)
#
# 0
# official
#
# 1
# name
#
# 2
# codonopsis
#
# 3
# radix
#
# 4
# english

# %%
getRankedFrequency(corpus)
# Out:
# [('will', 4860),
#  ('hong', 4813),
#  ('say', 4788),
#  ('use', 4730),
#  ('make', 4497),
#  ('one', 4493),
#  ('kong', 4011),
#  ('time', 3641),
#  ('help', 3572),
#  ('health', 3399),
#  ('take', 3332),
#  ('body', 3248),
#  ('may', 3086),
#  ('people', 3006),
#  ('day', 2953),
#  ('go', 2895),
#  ('find', 2697),
#  ('good', 2609),
#  ('food', 2605),
#  ('work', 2414),
#  ('youre', 2340),
#  ('need', 2327),
#  ('know', 2309),
#  ('look', 2280),
#  ('include', 2247),
#  ('new', 2211),
#  ('year', 2070),
#  ('life', 2037),
#  ('even', 2030),
#  ('way', 2019),
#  ('best', 2004),
#  ('well', 1988),
#  ('many', 1958),
#  ('offer', 1849),
#  ('want', 1810),
#  ('u', 1784),
#  ('feel', 1780),
#  ('eat', 1764),
#  ('come', 1763),
#  ('cause', 1751),
#  ('skin', 1716),
#  ('dont', 1676),
#  ('high', 1662),
#  ('start', 1646),
#  ('back', 1634),
#  ('much', 1634),
#  ('keep', 1595),
#  ('image', 1542),
#  ('see', 1532),
#  ('first', 1528),
#  ('give', 1517),
#  ('experience', 1511),
#  ('product', 1484),
#  ('study', 1483),
#  ('woman', 1465),
#  ('try', 1445),
#  ('healthy', 1444),
#  ('every', 1423),
#  ('two', 1417),
#  ('water', 1366),
#  ('great', 1349),
#  ('think', 1349),
#  ('blood', 1346),
#  ('disease', 1340),
#  ('city', 1335),
#  ('provide', 1315),
#  ('thing', 1309),
#  ('drink', 1309),
#  ('diet', 1308),
#  ('right', 1305),
#  ('pain', 1304),
#  ('change', 1287),
#  ('sleep', 1281),
#  ('world', 1260),
#  ('service', 1220),
#  ('level', 1217),
#  ('show', 1215),
#  ('risk', 1208),
#  ('add', 1204),
#  ('now', 1201),
#  ('weight', 1195),
#  ('love', 1188),
#  ('place', 1183),
#  ('home', 1183),
#  ('treatment', 1152),
#  ('cancer', 1143),
#  ('oil', 1130),
#  ('long', 1128),
#  ('learn', 1128),
#  ('support', 1114),
#  ('information', 1110),
#  ('around', 1105),
#  ('close', 1089),
#  ('fat', 1076),
#  ('little', 1054),
#  ('exercise', 1054),
#  ('restaurant', 1050),
#  ('part', 1050),
#  ('hour', 1041),
#  ('child', 1037),
#  ('never', 1036),
#  ('shop', 1035),
#  ('result', 1035),
#  ('really', 1033),
#  ('sure', 1032),
#  ('effect', 1021),
#  ('spot', 1018),
#  ('increase', 1003),
#  ('bar', 1002),
#  ('week', 992),
#  ('via', 983),
#  ('heart', 979),
#  ('thats', 978),
#  ('2', 977),
#  ('problem', 977),
#  ('reduce', 973),
#  ('vitamin', 970),
#  ('hair', 963),
#  ('patient', 962),
#  ('still', 961),
#  ('courtesy', 957),
#  ('call', 952),
#  ('care', 951),
#  ('1', 948),
#  ('student', 945),
#  ('different', 944),
#  ('system', 929),
#  ('research', 927),
#  ('event', 924),
#  ('improve', 920),
#  ('dr', 917),
#  ('something', 913),
#  ('without', 910),
#  ('natural', 910),
#  ('head', 904),
#  ('family', 904),
#  ('low', 898),
#  ('medical', 896),
#  ('street', 893),
#  ('group', 893),
#  ('road', 888),
#  ('lead', 888),
#  ('age', 887),
#  ('often', 886),
#  ('doctor', 882),
#  ('always', 882),
#  ('might', 881),
#  ('open', 881),
#  ('become', 881),
#  ('important', 879),
#  ('tell', 876),
#  ('benefit', 874),
#  ('mean', 873),
#  ('symptom', 864),
#  ('live', 851),
#  ('area', 846),
#  ('sassy', 845),
#  ('special', 845),
#  ('three', 841),
#  ('easy', 835),
#  ('lot', 833),
#  ('stress', 832),
#  ('medicine', 831),
#  ('set', 827),
#  ('youll', 823),
#  ('protein', 815),
#  ('course', 795),
#  ('person', 793),
#  ('3', 791),
#  ('10', 789),
#  ('control', 788),
#  ('top', 787),
#  ('type', 787),
#  ('hand', 787),
#  ('accord', 786),
#  ('small', 786),
#  ('condition', 779),
#  ('share', 775),
#  ('treat', 773),
#  ('muscle', 771),
#  ('perfect', 769),
#  ('free', 767),
#  ('site', 766),
#  ('check', 755),
#  ('bring', 755),
#  ('available', 754),
#  ('month', 753),
#  ('im', 751),
#  ('another', 750),
#  ('big', 749),
#  ('order', 749),
#  ('create', 748),
#  ('point', 746),
#  ('contain', 742),
#  ('tea', 739),
#  ('follow', 739),
#  ('quality', 738),
#  ('girl', 734),
#  ('university', 730),
#  ('sugar', 728),
#  ('minute', 718),
#  ('leave', 718),
#  ('option', 716),
#  ('put', 712),
#  ('friend', 709),
#  ('side', 709),
#  ('away', 706),
#  ('form', 706),
#  ('meal', 705),
#  ('sex', 703),
#  ('modal', 702),
#  ('chinese', 700),
#  ('common', 698),
#  ('pound', 694),
#  ('daily', 694),
#  ('night', 689),
#  ('ask', 688),
#  ('let', 688),
#  ('ingredient', 680),
#  ('key', 679),
#  ('per', 678),
#  ('serve', 676),
#  ('guide', 676),
#  ('end', 663),
#  ('less', 662),
#  ('enjoy', 662),
#  ('content', 659),
#  ('central', 655),
#  ('recommend', 654),
#  ('whether', 653),
#  ('mind', 651),
#  ('lose', 650),
#  ('old', 650),
#  ('face', 649),
#  ('develop', 648),
#  ('book', 645),
#  ('amount', 644),
#  ('run', 641),
#  ('design', 641),
#  ('fruit', 639),
#  ('next', 638),
#  ('partner', 636),
#  ('eye', 636),
#  ('full', 633),
#  ('store', 633),
#  ('number', 632),
#  ('process', 629),
#  ('move', 627),
#  ('talk', 625),
#  ('5', 620),
#  ('activity', 620),
#  ('actually', 620),
#  ('baby', 613),
#  ('happy', 612),
#  ('along', 612),
#  ('enough', 608),
#  ('last', 607),
#  ('turn', 606),
#  ('cell', 605),
#  ('issue', 604),
#  ('energy', 601),
#  ('men', 599),
#  ('fresh', 598),
#  ('loss', 598),
#  ('choose', 598),
#  ('search', 597),
#  ('range', 597),
#  ('data', 595),
#  ('especially', 591),
#  ('plan', 589),
#  ('allow', 586),
#  ('reason', 583),
#  ('test', 581),
#  ('case', 580),
#  ('mental', 578),
#  ('prevent', 578),
#  ('hot', 572),
#  ('website', 572),
#  ('stay', 571),
#  ('cant', 570),
#  ('walk', 568),
#  ('hard', 567),
#  ('continue', 565),
#  ('feature', 564),
#  ('facebook', 563),
#  ('practice', 563),
#  ('personal', 560),
#  ('secret', 558),
#  ('light', 557),
#  ('source', 557),
#  ('understand', 555),
#  ('truly', 552),
#  ('sign', 552),
#  ('public', 542),
#  ('state', 540),
#  ('receive', 539),
#  ('doesnt', 537),
#  ('wine', 536),
#  ('affect', 536),
#  ('foot', 535),
#  ('online', 535),
#  ('read', 534),
#  ('bad', 529),
#  ('4', 526),
#  ('term', 526),
#  ('press', 524),
#  ('wan', 521),
#  ('stop', 520),
#  ('report', 520),
#  ('avoid', 519),
#  ('base', 516),
#  ('play', 516),
#  ('country', 516),
#  ('calorie', 514),
#  ('grow', 513),
#  ('able', 513),
#  ('school', 512),
#  ('green', 511),
#  ('large', 511),
#  ('others', 510),
#  ('whole', 508),
#  ('medium', 508),
#  ('news', 508),
#  ('visit', 503),
#  ('al', 502),
#  ('happen', 502),
#  ('usually', 502),
#  ('local', 502),
#  ('tip', 500),
#  ('simple', 500),
#  ('focus', 499),
#  ('strong', 498),
#  ('workout', 497),
#  ('name', 497),
#  ('social', 496),
#  ('cold', 496),
#  ('policy', 496),
#  ('house', 495),
#  ('early', 494),
#  ('physical', 493),
#  ('menu', 492),
#  ('consider', 492),
#  ('brain', 491),
#  ('post', 491),
#  ('list', 490),
#  ('20', 490),
#  ('2018', 488),
#  ('goto', 487),
#  ('everything', 487),
#  ('spend', 486),
#  ('dish', 484),
#  ('though', 484),
#  ('style', 482),
#  ('drug', 482),
#  ('beach', 481),
#  ('professional', 481),
#  ('example', 481),
#  ('young', 479),
#  ('please', 479),
#  ('human', 477),
#  ('fact', 475),
#  ('effective', 475),
#  ('price', 474),
#  ('four', 474),
#  ('second', 474),
#  ('position', 473),
#  ('together', 472),
#  ('choice', 471),
#  ('coffee', 467),
#  ('acid', 467),
#  ('due', 466),
#  ('write', 464),
#  ('morning', 464),
#  ('c', 464),
#  ('team', 463),
#  ('egg', 462),
#  ('brand', 462),
#  ('instagram', 461),
#  ('pressure', 461),
#  ('suggest', 460),
#  ('white', 460),
#  ('build', 459),
#  ('isnt', 458),
#  ('real', 458),
#  ('30', 458),
#  ('possible', 458),
#  ('travel', 457),
#  ('room', 456),
#  ('step', 455),
#  ('center', 455),
#  ('acupuncture', 452),
#  ('class', 451),
#  ('infection', 450),
#  ('theyre', 449),
#  ('favourite', 448),
#  ('didnt', 447),
#  ('balance', 447),
#  ('seem', 446),
#  ('must', 446),
#  ('meat', 445),
#  ('juice', 445),
#  ('hold', 445),
#  ('6', 444),
#  ('likely', 442),
#  ('apply', 441),
#  ('red', 441),
#  ('relationship', 441),
#  ('summer', 440),
#  ('least', 438),
#  ('training', 437),
#  ('view', 437),
#  ('fitness', 436),
#  ('require', 436),
#  ('late', 436),
#  ('member', 434),
#  ('sweet', 433),
#  ('five', 432),
#  ('disorder', 432),
#  ('window', 432),
#  ('therapy', 432),
#  ('line', 432),
#  ('cooky', 431),
#  ('begin', 431),
#  ('individual', 431),
#  ('contact', 430),
#  ('immune', 430),
#  ('milk', 428),
#  ('produce', 427),
#  ('cut', 426),
#  ('space', 425),
#  ('period', 425),
#  ('percent', 424),
#  ('gift', 421),
#  ('within', 421),
#  ('beer', 419),
#  ('function', 418),
#  ('escape', 417),
#  ('air', 415),
#  ('community', 414),
#  ('professor', 414),
#  ('anxiety', 413),
#  ('someone', 413),
#  ('deal', 412),
#  ('extra', 411),
#  ('activate', 411),
#  ('far', 411),
#  ('already', 411),
#  ('leg', 410),
#  ('supplement', 410),
#  ('company', 410),
#  ('cup', 409),
#  ('remedy', 409),
#  ('organic', 409),
#  ('present', 407),
#  ('button', 404),
#  ('taste', 404),
#  ('essential', 404),
#  ('wear', 403),
#  ('break', 400),
#  ('education', 400),
#  ('believe', 400),
#  ('stomach', 399),
#  ('idea', 399),
#  ('fresco', 398),
#  ('kind', 398),
#  ('expert', 398),
#  ('black', 397),
#  ('short', 397),
#  ('lifestyle', 396),
#  ('art', 395),
#  ('damage', 395),
#  ('addition', 395),
#  ('traditional', 395),
#  ('youve', 394),
#  ('note', 394),
#  ('reach', 394),
#  ('pavement', 393),
#  ('unique', 392),
#  ('ive', 389),
#  ('location', 389),
#  ('factor', 389),
#  ('holeinthewall', 388),
#  ('everyone', 388),
#  ('island', 387),
#  ('although', 387),
#  ('deep', 386),
#  ('diabetes', 384),
#  ('theres', 383),
#  ('selection', 382),
#  ('question', 382),
#  ('heat', 382),
#  ('publish', 381),
#  ('15', 380),
#  ('clean', 379),
#  ('instead', 379),
#  ('couple', 378),
#  ('clinical', 378),
#  ('yoga', 376),
#  ('buy', 376),
#  ('maintain', 376),
#  ('customer', 375),
#  ('video', 374),
#  ('challenge', 374),
#  ('8', 374),
#  ('beauty', 372),
#  ('today', 372),
#  ('piece', 371),
#  ('across', 371),
#  ('pick', 370),
#  ('regular', 370),
#  ('sometimes', 370),
#  ('explain', 370),
#  ('lung', 370),
#  ('complete', 369),
#  ('liver', 367),
#  ('cook', 366),
#  ('sit', 366),
#  ('property', 366),
#  ('animal', 365),
#  ('technology', 365),
#  ('cheese', 364),
#  ('american', 363),
#  ('centre', 362),
#  ('promote', 362),
#  ('vegan', 359),
#  ('pay', 359),
#  ('adult', 359),
#  ('program', 359),
#  ('general', 359),
#  ('meet', 359),
#  ('bay', 358),
#  ('fun', 358),
#  ('whats', 358),
#  ('remove', 358),
#  ('nutrient', 358),
#  ('nutrition', 357),
#  ('development', 357),
#  ('cover', 356),
#  ('kidney', 354),
#  ('100', 354),
#  ('environment', 353),
#  ('fill', 352),
#  ('clear', 350),
#  ('review', 349),
#  ('popular', 349),
#  ('article', 349),
#  ('fit', 349),
#  ('chicken', 348),
#  ('dry', 347),
#  ('matter', 346),
#  ('credit', 346),
#  ('fish', 345),
#  ('wont', 345),
#  ('guy', 344),
#  ('link', 344),
#  ('half', 344),
#  ('tai', 343),
#  ('certain', 343),
#  ('party', 342),
#  ('antioxidant', 342),
#  ('chance', 341),
#  ('date', 341),
#  ('role', 341),
#  ('teach', 340),
#  ('international', 340),
#  ('delicious', 339),
#  ('plus', 339),
#  ('massage', 339),
#  ('involve', 339),
#  ('7', 339),
#  ('photo', 338),
#  ('kongs', 338),
#  ('e', 337),
#  ('depression', 337),
#  ('several', 337),
#  ('medication', 337),
#  ('consume', 337),
#  ('associate', 337),
#  ('chronic', 337),
#  ('mother', 336),
#  ('various', 336),
#  ('bit', 335),
#  ('fast', 335),
#  ('rest', 335),
#  ('hit', 334),
#  ('parent', 334),
#  ('12', 334),
#  ('past', 334),
#  ('classic', 333),
#  ('yet', 332),
#  ('expect', 331),
#  ('attention', 331),
#  ('specific', 331),
#  ('anything', 330),
#  ('definitely', 330),
#  ('hospital', 330),
#  ('fiber', 329),
#  ('researcher', 329),
#  ('vegetable', 328),
#  ('hormone', 328),
#  ('stand', 328),
#  ('g', 328),
#  ('item', 327),
#  ('behind', 326),
#  ('d', 326),
#  ('national', 326),
#  ('rich', 326),
#  ('attack', 325),
#  ('among', 325),
#  ('safe', 323),
#  ('salt', 322),
#  ('difficult', 321),
#  ('goal', 321),
#  ('simply', 320),
#  ('market', 320),
#  ('positive', 320),
#  ('opportunity', 320),
#  ('story', 320),
#  ('office', 318),
#  ('snack', 317),
#  ('raise', 317),
#  ('boost', 317),
#  ('main', 317),
#  ('either', 317),
#  ('weve', 316),
#  ('meditation', 316),
#  ('size', 316),
#  ('ensure', 316),
#  ('lunch', 315),
#  ('man', 315),
#  ('hear', 315),
#  ('50', 315),
#  ('death', 315),
#  ('md', 314),
#  ('worth', 314),
#  ('almost', 312),
#  ('save', 312),
#  ('bone', 312),
#  ('breakfast', 311),
#  ('session', 311),
#  ('honey', 311),
#  ('impact', 310),
#  ('cool', 309),
#  ('bed', 309),
#  ('variety', 308),
#  ('felt', 308),
#  ('journey', 307),
#  ('busy', 307),
#  ('normal', 307),
#  ('kid', 306),
#  ('breast', 306),
#  ('gym', 305),
#  ('suffer', 305),
#  ('enter', 305),
#  ('explore', 304),
#  ('action', 303),
#  ('probably', 302),
#  ('kowloon', 302),
#  ('account', 302),
#  ('season', 302),
#  ('google', 301),
#  ('watch', 301),
#  ('weekend', 300),
#  ('click', 300),
#  ('cream', 299),
#  ('dinner', 299),
#  ('access', 299),
#  ('throughout', 299),
#  ('production', 298),
#  ('easily', 298),
#  ('business', 298),
#  ('email', 297),
#  ('protect', 297),
#  ('limit', 297),
#  ('address', 297),
#  ('author', 296),
#  ('peace', 296),
#  ('floor', 295),
#  ('quite', 295),
#  ('feeling', 295),
#  ('ready', 294),
#  ('nothing', 294),
#  ('rate', 294),
#  ('future', 293),
#  ('cholesterol', 291),
#  ('movement', 291),
#  ('mix', 290),
#  ('fashion', 289),
#  ('sport', 289),
#  ('miss', 288),
#  ('music', 288),
#  ('technique', 288),
#  ('burn', 288),
#  ('later', 287),
#  ('material', 287),
#  ('notice', 287),
#  ('arm', 285),
#  ('advice', 285),
#  ('shes', 284),
#  ('flow', 283),
#  ('sun', 282),
#  ('client', 282),
#  ('ability', 282),
#  ('pretty', 281),
#  ('bottle', 281),
#  ('detail', 281),
#  ('release', 281),
#  ('dog', 281),
#  ('similar', 281),
#  ('select', 281),
#  ('salad', 280),
#  ('train', 280),
#  ('trial', 280),
#  ('method', 280),
#  ('discount', 279),
#  ('sunday', 279),
#  ('pregnancy', 278),
#  ('plenty', 278),
#  ('true', 278),
#  ('approach', 278),
#  ('difference', 277),
#  ('privacy', 277),
#  ('routine', 277),
#  ('pack', 276),
#  ('occur', 276),
#  ('inside', 276),
#  ('gain', 276),
#  ('wait', 275),
#  ('park', 275),
#  ('carry', 275),
#  ('outside', 274),
#  ('quickly', 274),
#  ('joint', 274),
#  ('china', 274),
#  ('2017', 273),
#  ('serious', 273),
#  ('code', 272),
#  ('cocktail', 271),
#  ('growth', 271),
#  ('core', 271),
#  ('six', 270),
#  ('seed', 270),
#  ('power', 270),
#  ('send', 270),
#  ('habit', 269),
#  ('learning', 269),
#  ('fall', 269),
#  ('m', 269),
#  ('b', 269),
#  ('nature', 269),
#  ('sound', 268),
#  ('science', 268),
#  ('collection', 268),
#  ('town', 267),
#  ('fan', 267),
#  ('global', 267),
#  ('lift', 267),
#  ('soup', 267),
#  ('inflammation', 266),
#  ('director', 266),
#  ('evidence', 266),
#  ('major', 266),
#  ('worry', 265),
#  ('asia', 265),
#  ('combine', 265),
#  ('plastic', 264),
#  ('manage', 264),
#  ('dark', 264),
#  ('join', 264),
#  ('fine', 264),
#  ('hk', 264),
#  ('glass', 263),
#  ('deliver', 263),
#  ('bag', 262),
#  ('star', 262),
#  ('appear', 262),
#  ('bacteria', 262),
#  ('journal', 261),
#  ('job', 261),
#  ('page', 261),
#  ('achieve', 261),
#  ('relate', 261),
#  ('hip', 260),
#  ('beautiful', 260),
#  ('perform', 260),
#  ('word', 260),
#  ('lemon', 259),
#  ('tsui', 259),
#  ('million', 259),
#  ('allergy', 259),
#  ('raw', 259),
#  ('moment', 259),
#  ('decide', 257),
#  ('building', 257),
#  ('illness', 257),
#  ('quick', 256),
#  ('delivery', 256),
#  ('birth', 255),
#  ('straight', 255),
#  ('rice', 254),
#  ('drive', 254),
#  ('enhance', 254),
#  ('wide', 253),
#  ('prepare', 253),
#  ('remember', 252),
#  ('intake', 252),
#  ('dress', 252),
#  ('living', 252),
#  ('sha', 251),
#  ('hotel', 251),
#  ('40', 251),
#  ('award', 250),
#  ('box', 250),
#  ('stage', 250),
#  ('potential', 250),
#  ('depend', 250),
#  ('history', 250),
#  ('sell', 249),
#  ('fight', 249),
#  ('strength', 249),
#  ('kitchen', 248),
#  ('touch', 248),
#  ('soon', 248),
#  ('table', 247),
#  ('soft', 246),
#  ('hike', 246),
#  ('value', 245),
#  ('thanks', 244),
#  ('neck', 244),
#  ('response', 244),
#  ('warm', 244),
#  ('concern', 243),
#  ('accept', 243),
#  ('culture', 243),
#  ('purpose', 243),
#  ('sense', 243),
#  ('wedding', 242),
#  ('alternative', 242),
#  ('standard', 242),
#  ('iron', 241),
#  ('lack', 241),
#  ('modern', 241),
#  ('compare', 240),
#  ('catch', 240),
#  ('anyone', 239),
#  ('relax', 239),
#  ('color', 239),
#  ('sai', 238),
#  ('burger', 238),
#  ('bite', 237),
#  ('shoulder', 237),
#  ('tissue', 237),
#  ('active', 237),
#  ('drop', 236),
#  ('apple', 236),
#  ('programme', 236),
#  ('aim', 236),
#  ('flavour', 235),
#  ('arent', 235),
#  ('recent', 235),
#  ('project', 235),
#  ('chemical', 235),
#  ('severe', 235),
#  ('calcium', 235),
#  ('phone', 234),
#  ('naturally', 234),
#  ('pair', 233),
#  ('coconut', 233),
#  ('knee', 232),
#  ('beef', 232),
#  ('super', 232),
#  ('return', 232),
#  ('9', 232),
#  ('practitioner', 232),
#  ('act', 232),
#  ('chai', 231),
#  ('york', 231),
#  ('single', 231),
#  ('25', 230),
#  ('11', 230),
#  ('remain', 230),
#  ('nail', 229),
#  ('chocolate', 229),
#  ('middle', 229),
#  ('everyday', 229),
#  ('brunch', 227),
#  ('teacher', 227),
#  ('cost', 227),
#  ('overall', 227),
#  ('heal', 227),
#  ('rise', 227),
#  ('mineral', 226),
#  ('wash', 226),
#  ('june', 226),
#  ('seek', 226),
#  ('industry', 226),
#  ('assessment', 225),
#  ('wasnt', 225),
#  ('etc', 225),
#  ('organ', 225),
#  ('advertising', 224),
#  ('french', 224),
#  ('knowledge', 224),
#  ('tend', 224),
#  ('stuff', 223),
#  ('rid', 223),
#  ('sexual', 223),
#  ('inspire', 223),
#  ('identify', 223),
#  ('trail', 222),
#  ('bear', 222),
#  ('effort', 222),
#  ('currently', 222),
#  ('diagnose', 220),
#  ('trip', 219),
#  ('money', 219),
#  ('chest', 219),
#  ('gram', 219),
#  ('significant', 219),
#  ('section', 219),
#  ('current', 219),
#  ('mood', 218),
#  ('rather', 218),
#  ('necessary', 218),
#  ('participant', 217),
#  ('clinic', 217),
#  ('plant', 217),
#  ('register', 217),
#  ('july', 216),
#  ('slow', 216),
#  ('emotional', 216),
#  ('14', 216),
#  ('lean', 215),
#  ('engage', 215),
#  ('surgery', 215),
#  ('prevention', 215),
#  ('measure', 215),
#  ('hang', 214),
#  ('false', 214),
#  ('discover', 214),
#  ('virus', 214),
#  ('thought', 214),
#  ('recipe', 212),
#  ('2016', 212),
#  ('encourage', 212),
#  ('college', 212),
#  ('powerful', 212),
#  ('lower', 211),
#  ('highly', 211),
#  ('pop', 211),
#  ('interest', 211),
#  ('speak', 210),
#  ('particularly', 210),
#  ('tool', 210),
#  ('association', 210),
#  ('door', 209),
#  ('request', 209),
#  ('third', 209),
#  ('situation', 209),
#  ('forget', 208),
#  ('lie', 208),
#  ('mark', 208),
#  ('private', 207),
#  ('update', 207),
#  ('yes', 207),
#  ('entire', 207),
#  ('favorite', 206),
#  ('win', 206),
#  ('teaching', 206),
#  ('completely', 206),
#  ('beyond', 206),
#  ('management', 206),
#  ('huge', 205),
#  ('performance', 205),
#  ('collect', 205),
#  ('blog', 205),
#  ('shake', 204),
#  ('18', 204),
#  ('directly', 204),
#  ('stick', 203),
#  ('spread', 203),
#  ('user', 203),
#  ('average', 202),
#  ('application', 202),
#  ('metabolism', 202),
#  ('series', 202),
#  ('towards', 202),
#  ('italian', 201),
#  ('ideal', 201),
#  ('heavy', 201),
#  ('society', 201),
#  ('temperature', 200),
#  ('sweat', 200),
#  ('trainer', 200),
#  ('connect', 200),
#  ('2015', 200),
#  ('garden', 199),
#  ('push', 199),
#  ('welcome', 199),
#  ('contribute', 199),
#  ...]

# %%
def vectorise(s):
    return dictionary.doc2bow(s)
    
corpus["text_vec"] = corpus["text_lem"].apply(vectorise)
# Out:
# /home/rebootaihk/anaconda3/envs/text/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# The text_vec column is the actual corpus, words are encoded as in the dictionary
corpora.MmCorpus.serialize('data/corpus.mm', corpus["text_vec"])

# %%
dictionary.save('data/dictionary.dict')

# %%
corpus.to_csv("data/corpus_df.csv")

# %%
corpus
# Out:
#                                                text_lem  \
# 0     [official, name, codonopsis, radix, english, n...
# 1     [tell, u, story, become, interested, public, h...
# 2     [please, make, sure, enter, valid, complete, n...
# 3     [hong, kong, association, organize, event, ele...
# 4     [electric, vehicle, charge, station, pop, ever...
# 5     [traditional, chinese, medicine, tcm, 2000, ye...
# 6     [select, one, following, topic, learn, chinese...
# 7     [western, physiology, urine, consider, fluid, ...
# 8     [coriolus, versicolor, know, versicolor, name,...
# 9     [mushroom, health, supplement, combine, benefi...
# 10    [color, scheme, hyy, product, packaging, base,...
# 11    [part, integrate, chinese, medicine, holding, ...
# 12    [immune, system, require, balance, harmony, or...
# 13    [lung, responsible, breathe, addition, chinese...
# 14    [healthy, cardiovascular, system, ensure, oxyg...
# 15    [chinese, medicine, believe, exercise, underta...
# 16    [liver, play, several, vital, function, body, ...
# 17    [kidney, urinary, system, play, vital, role, b...
# 18    [western, physiology, spleen, large, vascular,...
# 19    [traditional, chinese, medicine, tcm, valuable...
# 20    [accord, u, national, cancer, foundation, one,...
# 21    [accord, u, national, cancer, foundation, one,...
# 22    [integrate, chinese, medicine, holding, ltd, s...
# 23    [coriolus, versicolor, know, yunzhi, precious,...
# 24    [make, unique, proprietary, ingredient, extrac...
# 25    [imyunity, dog, wellresearched, mushroom, supp...
# 26    [report, true, side, effect, use, imyunity, re...
# 27    [product, develop, professional, thorough, und...
# 28    [product, introduce, website, develop, profess...
# 29    [distributor, list, contact, page, authorize, ...
# ...                                                 ...
# 2578  [cnn, student, university, houston, new, medic...
# 2579  [cnnan, outbreak, salmonella, link, raw, turke...
# 2580  [north, carolina, football, coach, larry, fire...
# 2581  [teacher, flight, florida, visit, parent, frie...
# 2582  [prepare, cannabis, cultivation, production, m...
# 2583  [cnna, grocery, store, chain, recall, pasta, s...
# 2584  [cnna, mass, radio, campaign, encourage, paren...
# 2585  [one, first, major, act, act, director, u, env...
# 2586  [spell, large, letter, chalkboard, classroom, ...
# 2587  [monday, website, national, guideline, provide...
# 2588  [health, expert, home, arent, make, decision, ...
# 2589  [rate, liver, cancer, increase, 43, american, ...
# 2590  [cnn, massachusetts, supreme, court, rule, mon...
# 2591  [go, parent, help, think, severe, sunburn, wor...
# 2592  [cnna, common, drug, use, control, blood, pres...
# 2593  [month, ask, take, plunge, now, kid, phone, in...
# 2594  [cnnthe, southern, indian, state, announce, mo...
# 2595  [might, able, blame, heat, bad, decision, smal...
# 2596  [20, living, type, 1, diabetes, mean, depend, ...
# 2597  [cnn, often, think, different, life, know, tee...
# 2598  [people, blood, pressure, marker, brain, disea...
# 2599  [cnnthe, british, association, sexual, health,...
# 2600  [hospital, call, think, might, routine, hop, g...
# 2601  [cnn, color, bubble, gum, flamingo, cotton, ca...
# 2602  [first, time, compulsive, sexual, behavior, co...
# 2603  [experiment, global, implication, australian, ...
# 2604  [florida, cnnthe, word, save, crystal, champ, ...
# 2605  [ageing, society, become, one, todays, world, ...
# 2606  [cnnan, outbreak, cyclospora, link, mcdonalds,...
# 2607  [remain, find, turkey, believe, show, evidence...
#
#                                                text_vec
# 0     [(0, 4), (1, 16), (2, 3), (3, 2), (4, 4), (5, ...
# 1     [(9, 4), (37, 2), (40, 1), (46, 1), (47, 2), (...
# 2     [(1, 1), (148, 2), (193, 1), (194, 1), (195, 1...
# 3     [(193, 1), (201, 1), (203, 2), (204, 4), (205,...
# 4     [(40, 2), (78, 1), (101, 1), (112, 1), (142, 1...
# 5     [(6, 1), (13, 3), (31, 1), (45, 1), (49, 1), (...
# 6     [(13, 4), (26, 1), (73, 1), (90, 1), (135, 1),...
# 7     [(13, 6), (19, 5), (28, 1), (30, 9), (31, 1), ...
# 8     [(1, 2), (11, 7), (13, 6), (31, 10), (32, 1), ...
# 9     [(1, 2), (6, 1), (11, 8), (13, 13), (31, 17), ...
# 10    [(13, 4), (36, 1), (37, 1), (40, 1), (45, 1), ...
# 11    [(1, 1), (13, 13), (31, 3), (47, 2), (52, 6), ...
# 12    [(94, 1), (328, 1), (334, 1), (347, 1), (349, ...
# 13    [(13, 1), (94, 1), (134, 1), (358, 1), (364, 1...
# 14    [(13, 1), (94, 2), (134, 1), (299, 1), (320, 2...
# 15    [(13, 2), (99, 1), (301, 1), (384, 1), (394, 1...
# 16    [(13, 1), (52, 1), (134, 1), (320, 1), (347, 1...
# 17    [(13, 1), (73, 1), (94, 2), (320, 2), (327, 1)...
# 18    [(13, 2), (19, 1), (43, 1), (110, 1), (170, 1)...
# 19    [(1, 1), (13, 5), (40, 1), (41, 1), (45, 1), (...
# 20    [(6, 1), (13, 7), (23, 5), (26, 8), (28, 2), (...
# 21    [(6, 1), (13, 1), (31, 1), (38, 2), (42, 1), (...
# 22    [(13, 1), (50, 1), (135, 1), (143, 1), (147, 2...
# 23    [(13, 2), (31, 4), (32, 1), (37, 1), (38, 4), ...
# 24    [(35, 1), (98, 1), (135, 1), (145, 1), (147, 1...
# 25    [(23, 5), (26, 2), (38, 2), (52, 2), (135, 3),...
# 26    [(13, 3), (26, 6), (28, 2), (31, 5), (32, 1), ...
# 27    [(13, 1), (52, 1), (99, 1), (104, 1), (128, 1)...
# 28    [(1, 2), (13, 16), (31, 1), (37, 2), (40, 1), ...
# 29    [(13, 1), (47, 1), (57, 2), (136, 1), (193, 1)...
# ...                                                 ...
# 2578  [(44, 1), (90, 1), (138, 1), (146, 1), (162, 1...
# 2579  [(44, 1), (47, 1), (84, 1), (90, 1), (138, 1),...
# 2580  [(44, 1), (90, 1), (138, 1), (162, 1), (171, 1...
# 2581  [(44, 1), (90, 1), (138, 1), (162, 1), (171, 1...
# 2582  [(0, 1), (42, 1), (44, 1), (46, 1), (47, 1), (...
# 2583  [(44, 1), (57, 1), (64, 1), (90, 1), (138, 1),...
# 2584  [(36, 1), (44, 1), (90, 1), (138, 1), (162, 1)...
# 2585  [(44, 1), (47, 1), (90, 1), (91, 1), (138, 1),...
# 2586  [(44, 1), (78, 1), (90, 1), (138, 1), (162, 1)...
# 2587  [(44, 1), (90, 1), (101, 1), (138, 1), (147, 1...
# 2588  [(52, 2), (127, 1), (144, 1), (194, 1), (232, ...
# 2589  [(44, 1), (47, 1), (52, 1), (84, 1), (90, 1), ...
# 2590  [(44, 1), (90, 1), (138, 1), (162, 1), (171, 1...
# 2591  [(44, 1), (56, 1), (90, 1), (134, 1), (138, 1)...
# 2592  [(44, 1), (47, 1), (90, 1), (100, 1), (134, 1)...
# 2593  [(44, 1), (90, 1), (126, 1), (138, 1), (162, 1...
# 2594  [(44, 1), (90, 1), (138, 1), (146, 1), (162, 1...
# 2595  [(44, 1), (90, 1), (138, 1), (146, 2), (152, 1...
# 2596  [(44, 1), (65, 1), (67, 1), (90, 1), (113, 1),...
# 2597  [(37, 2), (44, 1), (90, 1), (126, 1), (138, 1)...
# 2598  [(84, 1), (116, 1), (136, 1), (156, 1), (189, ...
# 2599  [(37, 1), (44, 1), (52, 1), (90, 1), (99, 1), ...
# 2600  [(44, 1), (60, 1), (73, 1), (90, 1), (127, 1),...
# 2601  [(40, 1), (44, 1), (90, 1), (138, 1), (162, 1)...
# 2602  [(40, 1), (44, 1), (52, 2), (84, 1), (90, 1), ...
# 2603  [(44, 1), (90, 1), (138, 1), (162, 1), (171, 1...
# 2604  [(37, 1), (44, 1), (47, 1), (90, 1), (138, 1),...
# 2605  [(40, 1), (44, 2), (49, 1), (90, 1), (95, 1), ...
# 2606  [(0, 1), (44, 1), (52, 1), (90, 1), (138, 1), ...
# 2607  [(37, 1), (44, 1), (90, 1), (136, 1), (138, 1)...
#
# [2607 rows x 2 columns]
